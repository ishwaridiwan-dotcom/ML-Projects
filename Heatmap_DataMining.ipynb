# %%
# from pandas import read_csv, to_datetime,DataFrame, Series
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import GridSearchCV
# from sklearn.linear_model import SGDRegressor
# from plotly import graph_objs, figure_factory

# data1 = read_csv("/content/DataMiningCa1 _Compiled Data .csv")
# data1.head()
# data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Columns: 117 entries, CountyName to PurposeOfRating_Unknown
# dtypes: float64(69), int64(25), object(23)
# memory usage: 178.5+ MB

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as mtb

data = pd.read_csv("/content/DataMiningCa1 _Compiled Data .csv")

sb.heatmap(data.corr(), annot=True, annot_kws={'size': 15})

mtb.show()
# Out:
# <ipython-input-4-71743b06fc4c>:8: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
from pandas import read_csv, to_datetime,DataFrame, Series
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDRegressor
from plotly import graph_objs, figure_factory

data1 = read_csv("/content/DataMiningCa1 _Compiled Data .csv")
data1.head()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Columns: 117 entries, CountyName to PurposeOfRating_Unknown
# dtypes: float64(69), int64(25), object(23)
# memory usage: 178.5+ MB

# %%
#  Heatmap
correlation  = data1.corr()
f = figure_factory.create_annotated_heatmap(correlation.values,list(correlation.columns),list(correlation.columns),correlation.round(2).values,showscale=False)
f.show()
# Out:
# <ipython-input-6-66b0a798888e>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv("/content/DataMiningCa1 _Compiled Data .csv")

# Create a DataFrame from the random data
df = pd.DataFrame(data)

# Compute the correlation matrix
corr_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(20, 15))  # Adjust the figure size as needed
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False)  # Set annot=True to display correlation values
plt.title('Correlation Heatmap of Variables')
plt.show()
# Out:
# <ipython-input-8-6b90251ed179>:13: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
# Dividing dataset into label and feature sets
X = data.drop(['quality'], axis = 1) # Features
Y = data['quality'] # Labels
print(X.shape)
print(Y.shape)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt




data = pd.read_csv("/content/DataMiningCa1 _Compiled Data .csv")

# Create a DataFrame from the random data
df = pd.DataFrame(data)

# Compute the correlation matrix
corr_matrix = df.corr()

# Plot the heatmap with labels
plt.figure(figsize=(20, 15))  # Adjust the figure size as needed
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False, xticklabels=corr_matrix.columns, yticklabels=corr_matrix.columns)
plt.title('Correlation Heatmap of Variables')
plt.show()
# Out:
# <ipython-input-9-316bb8823f5c>:15: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
import pandas as pd
import numpy as np

# Assuming you have a DataFrame 'df' with your data
data = pd.read_csv("/content/DataMiningCa1 _Compiled Data .csv")

# Create a DataFrame from the random data
df = pd.DataFrame(data)
# Compute the correlation matrix
corr_matrix = df.corr()

# Set a threshold for correlation coefficient
threshold = 0.7  # You can adjust this threshold as needed

# Find pairs of highly correlated variables
correlated_pairs = []

# Iterate over each variable
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > threshold:  # Check correlation coefficient against threshold
            correlated_pairs.append((corr_matrix.columns[i], corr_matrix.columns[j]))

# Print correlated variable pairs
for pair in correlated_pairs:
    print(pair)
# Out:
# <ipython-input-10-baa2d65964ff>:10: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# ('BerRating', 'CO2Rating')
# ('BerRating', 'MPCDERValue')
# ('GroundFloorArea(sq m)', 'WallArea')
# ('GroundFloorArea(sq m)', 'RoofArea')
# ('GroundFloorArea(sq m)', 'FloorArea')
# ('GroundFloorArea(sq m)', 'WindowArea')
# ('GroundFloorArea(sq m)', 'DistributionLosses')
# ('GroundFloorArea(sq m)', 'DeliveredLightingEnergy')
# ('GroundFloorArea(sq m)', 'PrimaryEnergyLighting')
# ('GroundFloorArea(sq m)', 'CO2Lighting')
# ('GroundFloorArea(sq m)', 'GroundFloorArea')
# ('WallArea', 'DistributionLosses')
# ('WallArea', 'DeliveredLightingEnergy')
# ('WallArea', 'PrimaryEnergyLighting')
# ('WallArea', 'CO2Lighting')
# ('RoofArea', 'FloorArea')
# ('RoofArea', 'DistributionLosses')
# ('RoofArea', 'DeliveredLightingEnergy')
# ...

# %%
import pandas as pd
import numpy as np

# Assuming you have a DataFrame 'df' with your data

# Compute the correlation matrix
corr_matrix = df.corr()

# Set a threshold for correlation coefficient
threshold = 0.7  # You can adjust this threshold as needed

# Find pairs of highly correlated variables
correlated_pairs = []

# Iterate over each variable
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > threshold:  # Check correlation coefficient against threshold
            correlated_pairs.append((corr_matrix.columns[i], corr_matrix.columns[j], corr_matrix.iloc[i, j]))

# Print correlated variable pairs with correlation coefficient
for pair in correlated_pairs:
    print(f"Correlated Variables: {pair[0]}, {pair[1]}, Correlation Coefficient: {pair[2]}")
# Out:
# <ipython-input-11-9efb4baf8cb0>:7: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Correlated Variables: BerRating, CO2Rating, Correlation Coefficient: 0.9607738468085596
# Correlated Variables: BerRating, MPCDERValue, Correlation Coefficient: 0.763898585902731
# Correlated Variables: GroundFloorArea(sq m), WallArea, Correlation Coefficient: 0.8345447721089195
# Correlated Variables: GroundFloorArea(sq m), RoofArea, Correlation Coefficient: 0.7970033057487725
# Correlated Variables: GroundFloorArea(sq m), FloorArea, Correlation Coefficient: 0.7875974390728653
# Correlated Variables: GroundFloorArea(sq m), WindowArea, Correlation Coefficient: 0.7664304374755615
# Correlated Variables: GroundFloorArea(sq m), DistributionLosses, Correlation Coefficient: 0.8368687177074172
# ...

# %%
# Dividing dataset into label and feature sets
X = data.drop(['quality'], axis = 1) # Features
Y = data['quality'] # Labels
